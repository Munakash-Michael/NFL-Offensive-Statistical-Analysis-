# %% [markdown]
# #### Libraries

# %%
import requests
import pandas as pd 
from bs4 import BeautifulSoup as bs 
import matplotlib.pyplot as plt

# %% [markdown]
# #### Grabbing Passing Stats

# %%
twenty_three_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2023/reg/all"
twenty_two_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2022/reg/all"
twenty_one_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2021/reg/all"
twenty_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2020/reg/all"
nineteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2019/reg/all"
eighteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2018/reg/all"
seventeen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2017/reg/all"
sixteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2016/reg/all"
fifteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2015/reg/all"
fourteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2014/reg/all"
thirteen_passing_url = "https://www.nfl.com/stats/team-stats/offense/passing/2013/reg/all"

twenty_three_passing_response = requests.get(twenty_three_passing_url)
twenty_two_passing_response = requests.get(twenty_two_passing_url)
twenty_one_passing_response = requests.get(twenty_one_passing_url)
twenty_passing_response = requests.get(twenty_passing_url)
nineteen_passing_response = requests.get(nineteen_passing_url)
eighteen_passing_response = requests.get(eighteen_passing_url)
seventeen_passing_response = requests.get(seventeen_passing_url)
sixteen_passing_response = requests.get(sixteen_passing_url)
fifteen_passing_response = requests.get(fifteen_passing_url)
fourteen_passing_response = requests.get(fourteen_passing_url)
thirteen_passing_response = requests.get(thirteen_passing_url)

twenty_three_passing_soup = bs(twenty_three_passing_response.text, 'html.parser')
twenty_two_passing_soup = bs(twenty_two_passing_response.text, 'html.parser')
twenty_one_passing_soup = bs(twenty_one_passing_response.text, 'html.parser')
twenty_passing_soup = bs(twenty_passing_response.text, 'html.parser')
nineteen_passing_soup = bs(nineteen_passing_response.text, 'html.parser')
eighteen_passing_soup = bs(eighteen_passing_response.text, 'html.parser')
seventeen_passing_soup = bs(seventeen_passing_response.text, 'html.parser')
sixteen_passing_soup = bs(sixteen_passing_response.text, 'html.parser')
fifteen_passing_soup = bs(fifteen_passing_response.text, 'html.parser')
fourteen_passing_soup = bs(fourteen_passing_response.text, 'html.parser')
thirteen_passing_soup = bs(thirteen_passing_response.text, 'html.parser')

# %% [markdown]
# #### Grabbing Rushing Stats

# %%
twenty_three_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2023/reg/all"
twenty_two_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2022/reg/all"
twenty_one_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2021/reg/all"
twenty_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2020/reg/all"
nineteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2019/reg/all"
eighteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2018/reg/all"
seventeen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2017/reg/all"
sixteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2016/reg/all"
fifteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2015/reg/all"
fourteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2014/reg/all"
thirteen_rushing_url = "https://www.nfl.com/stats/team-stats/offense/rushing/2013/reg/all"

twenty_three_rushing_response = requests.get(twenty_three_rushing_url)
twenty_two_rushing_response = requests.get(twenty_two_rushing_url)
twenty_one_rushing_response = requests.get(twenty_one_rushing_url)
twenty_rushing_response = requests.get(twenty_rushing_url)
nineteen_rushing_response = requests.get(nineteen_rushing_url)
eighteen_rushing_response = requests.get(eighteen_rushing_url)
seventeen_rushing_response = requests.get(seventeen_rushing_url)
sixteen_rushing_response = requests.get(sixteen_rushing_url)
fifteen_rushing_response = requests.get(fifteen_rushing_url)
fourteen_rushing_response = requests.get(fourteen_rushing_url)
thirteen_rushing_response = requests.get(thirteen_rushing_url)

twenty_three_rushing_soup = bs(twenty_three_rushing_response.text, 'html.parser')
twenty_two_rushing_soup = bs(twenty_two_rushing_response.text, 'html.parser')
twenty_one_rushing_soup = bs(twenty_one_rushing_response.text, 'html.parser')
twenty_rushing_soup = bs(twenty_rushing_response.text, 'html.parser')
nineteen_rushing_soup = bs(nineteen_rushing_response.text, 'html.parser')
eighteen_rushing_soup = bs(eighteen_rushing_response.text, 'html.parser')
seventeen_rushing_soup = bs(seventeen_rushing_response.text, 'html.parser')
sixteen_rushing_soup = bs(sixteen_rushing_response.text, 'html.parser')
fifteen_rushing_soup = bs(fifteen_rushing_response.text, 'html.parser')
fourteen_rushing_soup = bs(fourteen_rushing_response.text, 'html.parser')
thirteen_rushing_soup = bs(thirteen_rushing_response.text, 'html.parser')

# %%
#Passing Stat Lists 
twenty_three_passing_team_name = []
twenty_three_passing_attempts = []
twenty_three_passing_completions = []
twenty_three_passing_completion_percentage = []
twenty_three_passing_yards_per_attempt = []
twenty_three_passing_yards = []
twenty_three_passing_touchdowns = []
twenty_three_passing_interceptions = []
twenty_three_year = []

twenty_two_passing_team_name = []
twenty_two_passing_attempts = []
twenty_two_passing_completion_percentage = []
twenty_two_passing_completions = []
twenty_two_passing_yards_per_attempt = []
twenty_two_passing_yards = []
twenty_two_passing_touchdowns = []
twenty_two_passing_interceptions = []
twenty_two_year = []

twenty_one_passing_team_name = []
twenty_one_passing_attempts = []
twenty_one_passing_completions = []
twenty_one_passing_completion_percentage = []
twenty_one_passing_yards_per_attempt = []
twenty_one_passing_yards = []
twenty_one_passing_touchdowns = []
twenty_one_passing_interceptions = []
twenty_one_year = []

twenty_passing_team_name = []
twenty_passing_attempts = []
twenty_passing_completions = []
twenty_passing_completion_percentage = []
twenty_passing_yards_per_attempt = []
twenty_passing_yards = []
twenty_passing_touchdowns = []
twenty_passing_interceptions = []
twenty_year = []

nineteen_passing_team_name = []
nineteen_passing_attempts = []
nineteen_passing_completions = []
nineteen_passing_completion_percentage = []
nineteen_passing_yards_per_attempt = []
nineteen_passing_yards = []
nineteen_passing_touchdowns = []
nineteen_passing_interceptions = []
nineteen_year = []

eighteen_passing_team_name = []
eighteen_passing_attempts = []
eighteen_passing_completions = []
eighteen_passing_completion_percentage = []
eighteen_passing_yards_per_attempt = []
eighteen_passing_yards = []
eighteen_passing_touchdowns = []
eighteen_passing_interceptions = []
eighteen_year = []

seventeen_passing_team_name = []
seventeen_passing_attempts = []
seventeen_passing_completions = []
seventeen_passing_completion_percentage = []
seventeen_passing_yards_per_attempt = []
seventeen_passing_yards = []
seventeen_passing_touchdowns = []
seventeen_passing_interceptions = []
seventeen_year = []

sixteen_passing_team_name = []
sixteen_passing_attempts = []
sixteen_passing_completions = []
sixteen_passing_completion_percentage = []
sixteen_passing_yards_per_attempt = []
sixteen_passing_yards = []
sixteen_passing_touchdowns = []
sixteen_passing_interceptions = []
sixteen_year = []

fifteen_passing_team_name = []
fifteen_passing_attempts = []
fifteen_passing_completions = []
fifteen_passing_completion_percentage = []
fifteen_passing_yards_per_attempt = []
fifteen_passing_yards = []
fifteen_passing_touchdowns = []
fifteen_passing_interceptions = []
fifteen_year = []

fourteen_passing_team_name = []
fourteen_passing_attempts = []
fourteen_passing_completions = []
fourteen_passing_completion_percentage = []
fourteen_passing_yards_per_attempt = []
fourteen_passing_yards = []
fourteen_passing_touchdowns = []
fourteen_passing_interceptions = []
fourteen_year = []

thirteen_passing_team_name = []
thirteen_passing_attempts = []
thirteen_passing_completions = []
thirteen_passing_completion_percentage = []
thirteen_passing_yards_per_attempt = []
thirteen_passing_yards = []
thirteen_passing_touchdowns = []
thirteen_passing_interceptions = []
thirteen_year = []

#Rushing List
twenty_three_rushing_team_name = []
twenty_three_rushing_attempts = [None] * 32
twenty_three_rushing_yards = [None] * 32
twenty_three_yards_per_carry = [None] * 32
twenty_three_rushing_touchdowns = [None] * 32

twenty_two_rushing_team_name = []
twenty_two_rushing_attempts = [None] * 32
twenty_two_rushing_yards = [None] * 32
twenty_two_yards_per_carry = [None] * 32
twenty_two_rushing_touchdowns = [None] * 32 

twenty_one_rushing_team_name = []
twenty_one_rushing_attempts = [None] * 32
twenty_one_rushing_yards = [None] * 32
twenty_one_yards_per_carry = [None] * 32
twenty_one_rushing_touchdowns = [None] * 32

twenty_rushing_team_name = []
twenty_rushing_attempts = [None] * 32
twenty_rushing_yards = [None] * 32
twenty_yards_per_carry = [None] * 32
twenty_rushing_touchdowns = [None] * 32

nineteen_rushing_team_name = []
nineteen_rushing_attempts = [None] * 32
nineteen_rushing_yards = [None] * 32
nineteen_yards_per_carry = [None] * 32
nineteen_rushing_touchdowns = [None] * 32

eighteen_rushing_team_name = []
eighteen_rushing_attempts = [None] * 32
eighteen_rushing_yards = [None] * 32
eighteen_yards_per_carry = [None] * 32
eighteen_rushing_touchdowns = [None] * 32

seventeen_rushing_team_name = []
seventeen_rushing_attempts = [None] * 32
seventeen_rushing_yards = [None] * 32
seventeen_yards_per_carry = [None] * 32
seventeen_rushing_touchdowns = [None] * 32

sixteen_rushing_team_name = []
sixteen_rushing_attempts = [None] * 32
sixteen_rushing_yards = [None] * 32
sixteen_yards_per_carry = [None] * 32
sixteen_rushing_touchdowns = [None] * 32

fifteen_rushing_team_name = []
fifteen_rushing_attempts = [None] * 32
fifteen_rushing_yards = [None] * 32
fifteen_yards_per_carry = [None] * 32
fifteen_rushing_touchdowns = [None] * 32

fourteen_rushing_team_name = []
fourteen_rushing_attempts = [None] * 32
fourteen_rushing_yards = [None] * 32
fourteen_yards_per_carry = [None] * 32
fourteen_rushing_touchdowns = [None] * 32

thirteen_rushing_team_name = []
thirteen_rushing_attempts = [None] * 32
thirteen_rushing_yards = [None] * 32
thirteen_yards_per_carry = [None] * 32
thirteen_rushing_touchdowns = [None] * 32

# %% [markdown]
# #### Get Data From Tables From Past 10 Seasons

# %%
#2023 Season
for twenty_three_passing_table in twenty_three_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_three_passing_titles = twenty_three_passing_table.find_all('th')
    twenty_three_passing_rows = twenty_three_passing_table.find_all('tr')
    
for twenty_three_passing_title in twenty_three_passing_titles:
    twenty_three_passing_tableTitles = [twenty_three_passing_title.text.strip() for twenty_three_passing_title in twenty_three_passing_titles]
    
for twenty_three_passing_team_names in twenty_three_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_three_passing_team_name.append(twenty_three_passing_team_names.text.strip())
    
for twenty_three_passing_row in twenty_three_passing_rows[1:]:
    twenty_three_passing_row_data = twenty_three_passing_row.find_all('td')
    twenty_three_passing_attempts.append(twenty_three_passing_row_data[1].text.strip())
    twenty_three_passing_completions.append(twenty_three_passing_row_data[2].text.strip())
    twenty_three_passing_completion_percentage.append(twenty_three_passing_row_data[3].text.strip())
    twenty_three_passing_yards_per_attempt.append(twenty_three_passing_row_data[4].text.strip())
    twenty_three_passing_yards.append(twenty_three_passing_row_data[5].text.strip())
    twenty_three_passing_touchdowns.append(twenty_three_passing_row_data[6].text.strip())
    twenty_three_passing_interceptions.append(twenty_three_passing_row_data[7].text.strip())
    twenty_three_year.append('2023')
    
twenty_three_passing_tableTitles[1] = "Pass Att"
twenty_three_passing_tableTitles[6] = "Pass TD"

for twenty_three_rushing_table in twenty_three_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_three_rushing_titles = twenty_three_rushing_table.find_all('th')
    twenty_three_rushing_rows = twenty_three_rushing_table.find_all('tr')

for twenty_three_rushing_title in twenty_three_rushing_titles:
    twenty_three_rushing_tableTitles = [twenty_three_rushing_title.text.strip() for title in twenty_three_rushing_titles]

for twenty_three_rushing_team_names in twenty_three_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_three_rushing_team_name.append(twenty_three_rushing_team_names.text.strip())

twenty_three_rushing_team_index = -1

for twenty_three_rushing_row in twenty_three_rushing_rows[1:]:
    twenty_three_rushing_row_data = twenty_three_rushing_row.find_all('td')
    twenty_three_rushing_team_index = twenty_three_rushing_team_index + 1
    twenty_three_team_index = twenty_three_passing_team_name.index(str(twenty_three_rushing_team_name[twenty_three_rushing_team_index]))
    twenty_three_rushing_attempts[twenty_three_team_index] = twenty_three_rushing_row_data[1].text.strip()
    twenty_three_rushing_yards[twenty_three_team_index] = twenty_three_rushing_row_data[2].text.strip()
    twenty_three_yards_per_carry[twenty_three_team_index] = twenty_three_rushing_row_data[3].text.strip()
    twenty_three_rushing_touchdowns[twenty_three_team_index] = twenty_three_rushing_row_data[4].text.strip()

twenty_three_rushing_tableTitles[1] = "Rush Att"
twenty_three_rushing_tableTitles[4] = "Rush TD"

#2022 Season

for twenty_two_passing_table in twenty_two_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_two_passing_titles = twenty_two_passing_table.find_all('th')
    twenty_two_passing_rows = twenty_two_passing_table.find_all('tr')
    
for twenty_two_passing_title in twenty_two_passing_titles:
    twenty_two_passing_tableTitles = [twenty_two_passing_title.text.strip() for twenty_two_passing_title in twenty_two_passing_titles]
    
for twenty_two_passing_team_names in twenty_two_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_two_passing_team_name.append(twenty_two_passing_team_names.text.strip())
    
for twenty_two_passing_row in twenty_two_passing_rows[1:]:
    twenty_two_passing_row_data = twenty_two_passing_row.find_all('td')
    twenty_two_passing_attempts.append(twenty_two_passing_row_data[1].text.strip())
    twenty_two_passing_completions.append(twenty_two_passing_row_data[2].text.strip())
    twenty_two_passing_completion_percentage.append(twenty_two_passing_row_data[3].text.strip())
    twenty_two_passing_yards_per_attempt.append(twenty_two_passing_row_data[4].text.strip())
    twenty_two_passing_yards.append(twenty_two_passing_row_data[5].text.strip())
    twenty_two_passing_touchdowns.append(twenty_two_passing_row_data[6].text.strip())
    twenty_two_passing_interceptions.append(twenty_two_passing_row_data[7].text.strip())
    twenty_two_year.append('2022')
    
twenty_two_passing_tableTitles[1] = "Pass Att"
twenty_two_passing_tableTitles[6] = "Pass TD"

for twenty_two_rushing_table in twenty_two_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_two_rushing_titles = twenty_two_rushing_table.find_all('th')
    twenty_two_rushing_rows = twenty_two_rushing_table.find_all('tr')

for twenty_two_rushing_title in twenty_two_rushing_titles:
    twenty_two_rushing_tableTitles = [twenty_two_rushing_title.text.strip() for title in twenty_two_rushing_titles]

for twenty_two_rushing_team_names in twenty_two_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_two_rushing_team_name.append(twenty_two_rushing_team_names.text.strip())

twenty_two_rushing_team_index = -1

for twenty_two_rushing_row in twenty_two_rushing_rows[1:]:
    twenty_two_rushing_row_data = twenty_two_rushing_row.find_all('td')
    twenty_two_rushing_team_index = twenty_two_rushing_team_index + 1
    twenty_two_team_index = twenty_two_passing_team_name.index(str(twenty_two_rushing_team_name[twenty_two_rushing_team_index]))
    twenty_two_rushing_attempts[twenty_two_team_index] = twenty_two_rushing_row_data[1].text.strip()
    twenty_two_rushing_yards[twenty_two_team_index] = twenty_two_rushing_row_data[2].text.strip()
    twenty_two_yards_per_carry[twenty_two_team_index] = twenty_two_rushing_row_data[3].text.strip()
    twenty_two_rushing_touchdowns[twenty_two_team_index] = twenty_two_rushing_row_data[4].text.strip()

twenty_two_rushing_tableTitles[1] = "Rush Att"
twenty_two_rushing_tableTitles[4] = "Rush TD"

#2021 Season

for twenty_one_passing_table in twenty_one_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_one_passing_titles = twenty_one_passing_table.find_all('th')
    twenty_one_passing_rows = twenty_one_passing_table.find_all('tr')
    
for twenty_one_passing_title in twenty_one_passing_titles:
    twenty_one_passing_tableTitles = [twenty_one_passing_title.text.strip() for twenty_one_passing_title in twenty_one_passing_titles]
    
for twenty_one_passing_team_names in twenty_one_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_one_passing_team_name.append(twenty_one_passing_team_names.text.strip())
    
for twenty_one_passing_row in twenty_one_passing_rows[1:]:
    twenty_one_passing_row_data = twenty_one_passing_row.find_all('td')
    twenty_one_passing_attempts.append(twenty_one_passing_row_data[1].text.strip())
    twenty_one_passing_completions.append(twenty_one_passing_row_data[2].text.strip())
    twenty_one_passing_completion_percentage.append(twenty_one_passing_row_data[3].text.strip())
    twenty_one_passing_yards_per_attempt.append(twenty_one_passing_row_data[4].text.strip())
    twenty_one_passing_yards.append(twenty_one_passing_row_data[5].text.strip())
    twenty_one_passing_touchdowns.append(twenty_one_passing_row_data[6].text.strip())
    twenty_one_passing_interceptions.append(twenty_one_passing_row_data[7].text.strip())
    twenty_one_year.append('2021')
    
twenty_one_passing_tableTitles[1] = "Pass Att"
twenty_one_passing_tableTitles[6] = "Pass TD"

for twenty_one_rushing_table in twenty_one_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_one_rushing_titles = twenty_one_rushing_table.find_all('th')
    twenty_one_rushing_rows = twenty_one_rushing_table.find_all('tr')

for twenty_one_rushing_title in twenty_one_rushing_titles:
    twenty_one_rushing_tableTitles = [twenty_one_rushing_title.text.strip() for title in twenty_one_rushing_titles]

for twenty_one_rushing_team_names in twenty_one_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_one_rushing_team_name.append(twenty_one_rushing_team_names.text.strip())

twenty_one_rushing_team_index = -1

for twenty_one_rushing_row in twenty_one_rushing_rows[1:]:
    twenty_one_rushing_row_data = twenty_one_rushing_row.find_all('td')
    twenty_one_rushing_team_index = twenty_one_rushing_team_index + 1
    twenty_one_team_index = twenty_one_passing_team_name.index(str(twenty_one_rushing_team_name[twenty_one_rushing_team_index]))
    twenty_one_rushing_attempts[twenty_one_team_index] = twenty_one_rushing_row_data[1].text.strip()
    twenty_one_rushing_yards[twenty_one_team_index] = twenty_one_rushing_row_data[2].text.strip()
    twenty_one_yards_per_carry[twenty_one_team_index] = twenty_one_rushing_row_data[3].text.strip()
    twenty_one_rushing_touchdowns[twenty_one_team_index] = twenty_one_rushing_row_data[4].text.strip()

twenty_one_rushing_tableTitles[1] = "Rush Att"
twenty_one_rushing_tableTitles[4] = "Rush TD"


#2020 Season
for twenty_passing_table in twenty_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_passing_titles = twenty_passing_table.find_all('th')
    twenty_passing_rows = twenty_passing_table.find_all('tr')
    
for twenty_passing_title in twenty_passing_titles:
    twenty_passing_tableTitles = [twenty_passing_title.text.strip() for twenty_passing_title in twenty_passing_titles]
    
for twenty_passing_team_names in twenty_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_passing_team_name.append(twenty_passing_team_names.text.strip())
    
for twenty_passing_row in twenty_passing_rows[1:]:
    twenty_passing_row_data = twenty_passing_row.find_all('td')
    twenty_passing_attempts.append(twenty_passing_row_data[1].text.strip())
    twenty_passing_completions.append(twenty_passing_row_data[2].text.strip())
    twenty_passing_completion_percentage.append(twenty_passing_row_data[3].text.strip())
    twenty_passing_yards_per_attempt.append(twenty_passing_row_data[4].text.strip())
    twenty_passing_yards.append(twenty_passing_row_data[5].text.strip())
    twenty_passing_touchdowns.append(twenty_passing_row_data[6].text.strip())
    twenty_passing_interceptions.append(twenty_passing_row_data[7].text.strip())
    twenty_year.append('2020')
    
twenty_passing_tableTitles[1] = "Pass Att"
twenty_passing_tableTitles[6] = "Pass TD"

for twenty_rushing_table in twenty_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    twenty_rushing_titles = twenty_rushing_table.find_all('th')
    twenty_rushing_rows = twenty_rushing_table.find_all('tr')

for twenty_rushing_title in twenty_rushing_titles:
    twenty_rushing_tableTitles = [twenty_rushing_title.text.strip() for title in twenty_rushing_titles]

for twenty_rushing_team_names in twenty_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    twenty_rushing_team_name.append(twenty_rushing_team_names.text.strip())

twenty_rushing_team_index = -1

for twenty_rushing_row in twenty_rushing_rows[1:]:
    twenty_rushing_row_data = twenty_rushing_row.find_all('td')
    twenty_rushing_team_index = twenty_rushing_team_index + 1
    twenty_team_index = twenty_passing_team_name.index(str(twenty_rushing_team_name[twenty_rushing_team_index]))
    twenty_rushing_attempts[twenty_team_index] = twenty_rushing_row_data[1].text.strip()
    twenty_rushing_yards[twenty_team_index] = twenty_rushing_row_data[2].text.strip()
    twenty_yards_per_carry[twenty_team_index] = twenty_rushing_row_data[3].text.strip()
    twenty_rushing_touchdowns[twenty_team_index] = twenty_rushing_row_data[4].text.strip()

twenty_rushing_tableTitles[1] = "Rush Att"
twenty_rushing_tableTitles[4] = "Rush TD"

#2019 Season
for nineteen_passing_table in nineteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    nineteen_passing_titles = nineteen_passing_table.find_all('th')
    nineteen_passing_rows = nineteen_passing_table.find_all('tr')
    
for nineteen_passing_title in nineteen_passing_titles:
    nineteen_passing_tableTitles = [nineteen_passing_title.text.strip() for nineteen_passing_title in nineteen_passing_titles]
    
for nineteen_passing_team_names in nineteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    nineteen_passing_team_name.append(nineteen_passing_team_names.text.strip())
    
for nineteen_passing_row in nineteen_passing_rows[1:]:
    nineteen_passing_row_data = nineteen_passing_row.find_all('td')
    nineteen_passing_attempts.append(nineteen_passing_row_data[1].text.strip())
    nineteen_passing_completions.append(nineteen_passing_row_data[2].text.strip())
    nineteen_passing_completion_percentage.append(nineteen_passing_row_data[3].text.strip())
    nineteen_passing_yards_per_attempt.append(nineteen_passing_row_data[4].text.strip())
    nineteen_passing_yards.append(nineteen_passing_row_data[5].text.strip())
    nineteen_passing_touchdowns.append(nineteen_passing_row_data[6].text.strip())
    nineteen_passing_interceptions.append(nineteen_passing_row_data[7].text.strip())
    nineteen_year.append('2019')
    
nineteen_passing_tableTitles[1] = "Pass Att"
nineteen_passing_tableTitles[6] = "Pass TD"

for nineteen_rushing_table in nineteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    nineteen_rushing_titles = nineteen_rushing_table.find_all('th')
    nineteen_rushing_rows = nineteen_rushing_table.find_all('tr')

for nineteen_rushing_title in nineteen_rushing_titles:
    nineteen_rushing_tableTitles = [nineteen_rushing_title.text.strip() for title in nineteen_rushing_titles]

for nineteen_rushing_team_names in nineteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    nineteen_rushing_team_name.append(nineteen_rushing_team_names.text.strip())

nineteen_rushing_team_index = -1

for nineteen_rushing_row in nineteen_rushing_rows[1:]:
    nineteen_rushing_row_data = nineteen_rushing_row.find_all('td')
    nineteen_rushing_team_index = nineteen_rushing_team_index + 1
    nineteen_team_index = nineteen_passing_team_name.index(str(nineteen_rushing_team_name[nineteen_rushing_team_index]))
    nineteen_rushing_attempts[nineteen_team_index] = nineteen_rushing_row_data[1].text.strip()
    nineteen_rushing_yards[nineteen_team_index] = nineteen_rushing_row_data[2].text.strip()
    nineteen_yards_per_carry[nineteen_team_index] = nineteen_rushing_row_data[3].text.strip()
    nineteen_rushing_touchdowns[nineteen_team_index] = nineteen_rushing_row_data[4].text.strip()

nineteen_rushing_tableTitles[1] = "Rush Att"
nineteen_rushing_tableTitles[4] = "Rush TD"

#2018 Season
for eighteen_passing_table in eighteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    eighteen_passing_titles = eighteen_passing_table.find_all('th')
    eighteen_passing_rows = eighteen_passing_table.find_all('tr')
    
for eighteen_passing_title in eighteen_passing_titles:
    eighteen_passing_tableTitles = [eighteen_passing_title.text.strip() for eighteen_passing_title in eighteen_passing_titles]
    
for eighteen_passing_team_names in eighteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    eighteen_passing_team_name.append(eighteen_passing_team_names.text.strip())
    
for eighteen_passing_row in eighteen_passing_rows[1:]:
    eighteen_passing_row_data = eighteen_passing_row.find_all('td')
    eighteen_passing_attempts.append(eighteen_passing_row_data[1].text.strip())
    eighteen_passing_completions.append(eighteen_passing_row_data[2].text.strip())
    eighteen_passing_completion_percentage.append(eighteen_passing_row_data[3].text.strip())
    eighteen_passing_yards_per_attempt.append(eighteen_passing_row_data[4].text.strip())
    eighteen_passing_yards.append(eighteen_passing_row_data[5].text.strip())
    eighteen_passing_touchdowns.append(eighteen_passing_row_data[6].text.strip())
    eighteen_passing_interceptions.append(eighteen_passing_row_data[7].text.strip())
    eighteen_year.append('2018')
    
eighteen_passing_tableTitles[1] = "Pass Att"
eighteen_passing_tableTitles[6] = "Pass TD"

for eighteen_rushing_table in eighteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    eighteen_rushing_titles = eighteen_rushing_table.find_all('th')
    eighteen_rushing_rows = eighteen_rushing_table.find_all('tr')

for eighteen_rushing_title in eighteen_rushing_titles:
    eighteen_rushing_tableTitles = [eighteen_rushing_title.text.strip() for title in eighteen_rushing_titles]

for eighteen_rushing_team_names in eighteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    eighteen_rushing_team_name.append(eighteen_rushing_team_names.text.strip())

eighteen_rushing_team_index = -1

for eighteen_rushing_row in eighteen_rushing_rows[1:]:
    eighteen_rushing_row_data = eighteen_rushing_row.find_all('td')
    eighteen_rushing_team_index = eighteen_rushing_team_index + 1
    eighteen_team_index = eighteen_passing_team_name.index(str(eighteen_rushing_team_name[eighteen_rushing_team_index]))
    eighteen_rushing_attempts[eighteen_team_index] = eighteen_rushing_row_data[1].text.strip()
    eighteen_rushing_yards[eighteen_team_index] = eighteen_rushing_row_data[2].text.strip()
    eighteen_yards_per_carry[eighteen_team_index] = eighteen_rushing_row_data[3].text.strip()
    eighteen_rushing_touchdowns[eighteen_team_index] = eighteen_rushing_row_data[4].text.strip()

eighteen_rushing_tableTitles[1] = "Rush Att"
eighteen_rushing_tableTitles[4] = "Rush TD"

#2017 Season 
for seventeen_passing_table in seventeen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    seventeen_passing_titles = seventeen_passing_table.find_all('th')
    seventeen_passing_rows = seventeen_passing_table.find_all('tr')

for seventeen_passing_title in seventeen_passing_titles:
    seventeen_passing_tableTitles = [seventeen_passing_title.text.strip() for seventeen_passing_title in seventeen_passing_titles]
    
for seventeen_team_name in seventeen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    seventeen_passing_team_name.append(seventeen_team_name.text.strip())
    
for seventeen_passing_row in seventeen_passing_rows[1:]:
    seventeen_passing_row_data = seventeen_passing_row.find_all('td')
    seventeen_passing_attempts.append(seventeen_passing_row_data[1].text.strip())
    seventeen_passing_completions.append(seventeen_passing_row_data[2].text.strip())
    seventeen_passing_completion_percentage.append(seventeen_passing_row_data[3].text.strip())
    seventeen_passing_yards_per_attempt.append(seventeen_passing_row_data[4].text.strip())
    seventeen_passing_yards.append(seventeen_passing_row_data[5].text.strip())
    seventeen_passing_touchdowns.append(seventeen_passing_row_data[6].text.strip())
    seventeen_passing_interceptions.append(seventeen_passing_row_data[7].text.strip())
    seventeen_year.append('2017')
    
seventeen_passing_tableTitles[1] = "Pass Att"
seventeen_passing_tableTitles[6] = "Pass TD"

for seventeen_rushing_table in seventeen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    seventeen_rushing_titles = seventeen_rushing_table.find_all('th')
    seventeen_rushing_rows = seventeen_rushing_table.find_all('tr')

for seventeen_rushing_title in seventeen_rushing_titles:
    seventeen_rushing_tableTitles = [seventeen_rushing_title.text.strip() for title in seventeen_rushing_titles]

for seventeen_rushing_team_names in seventeen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    seventeen_rushing_team_name.append(seventeen_rushing_team_names.text.strip())

seventeen_rushing_team_index = -1

for seventeen_rushing_row in seventeen_rushing_rows[1:]:
    seventeen_rushing_row_data = seventeen_rushing_row.find_all('td')
    seventeen_rushing_team_index = seventeen_rushing_team_index + 1
    seventeen_team_index = seventeen_passing_team_name.index(str(seventeen_rushing_team_name[seventeen_rushing_team_index]))
    seventeen_rushing_attempts[seventeen_team_index] = seventeen_rushing_row_data[1].text.strip()
    seventeen_rushing_yards[seventeen_team_index] = seventeen_rushing_row_data[2].text.strip()
    seventeen_yards_per_carry[seventeen_team_index] = seventeen_rushing_row_data[3].text.strip()
    seventeen_rushing_touchdowns[seventeen_team_index] = seventeen_rushing_row_data[4].text.strip()

seventeen_rushing_tableTitles[1] = "Rush Att"
seventeen_rushing_tableTitles[4] = "Rush TD"

#2016 Season
for sixteen_passing_table in sixteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    sixteen_passing_titles = sixteen_passing_table.find_all('th')
    sixteen_passing_rows = sixteen_passing_table.find_all('tr')

for sixteen_passing_title in sixteen_passing_titles:
    sixteen_passing_tableTitles = [sixteen_passing_title.text.strip() for sixteen_passing_title in sixteen_passing_titles]
    
for sixteen_team_name in sixteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    sixteen_passing_team_name.append(sixteen_team_name.text.strip())
    
for sixteen_passing_row in sixteen_passing_rows[1:]:
    sixteen_passing_row_data = sixteen_passing_row.find_all('td')
    sixteen_passing_attempts.append(sixteen_passing_row_data[1].text.strip())
    sixteen_passing_completions.append(sixteen_passing_row_data[2].text.strip())
    sixteen_passing_completion_percentage.append(sixteen_passing_row_data[3].text.strip())
    sixteen_passing_yards_per_attempt.append(sixteen_passing_row_data[4].text.strip())
    sixteen_passing_yards.append(sixteen_passing_row_data[5].text.strip())
    sixteen_passing_touchdowns.append(sixteen_passing_row_data[6].text.strip())
    sixteen_passing_interceptions.append(sixteen_passing_row_data[7].text.strip())
    sixteen_year.append('2016')
    
sixteen_passing_tableTitles[1] = "Pass Att"
sixteen_passing_tableTitles[6] = "Pass TD"

for sixteen_rushing_table in sixteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    sixteen_rushing_titles = sixteen_rushing_table.find_all('th')
    sixteen_rushing_rows = sixteen_rushing_table.find_all('tr')

for sixteen_rushing_title in sixteen_rushing_titles:
    sixteen_rushing_tableTitles = [sixteen_rushing_title.text.strip() for title in sixteen_rushing_titles]

for sixteen_rushing_team_names in sixteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    sixteen_rushing_team_name.append(sixteen_rushing_team_names.text.strip())

sixteen_rushing_team_index = -1

for sixteen_rushing_row in sixteen_rushing_rows[1:]:
    sixteen_rushing_row_data = sixteen_rushing_row.find_all('td')
    sixteen_rushing_team_index = sixteen_rushing_team_index + 1
    sixteen_team_index = sixteen_passing_team_name.index(str(sixteen_rushing_team_name[sixteen_rushing_team_index]))
    sixteen_rushing_attempts[sixteen_team_index] = sixteen_rushing_row_data[1].text.strip()
    sixteen_rushing_yards[sixteen_team_index] = sixteen_rushing_row_data[2].text.strip()
    sixteen_yards_per_carry[sixteen_team_index] = sixteen_rushing_row_data[3].text.strip()
    sixteen_rushing_touchdowns[sixteen_team_index] = sixteen_rushing_row_data[4].text.strip()

sixteen_rushing_tableTitles[1] = "Rush Att"
sixteen_rushing_tableTitles[4] = "Rush TD"

#2015 Season
for fifteen_passing_table in fifteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    fifteen_passing_titles = fifteen_passing_table.find_all('th')
    fifteen_passing_rows = fifteen_passing_table.find_all('tr')

for fifteen_passing_title in fifteen_passing_titles:
    fifteen_passing_tableTitles = [fifteen_passing_title.text.strip() for fifteen_passing_title in fifteen_passing_titles]
    
for fifteen_team_name in fifteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    fifteen_passing_team_name.append(fifteen_team_name.text.strip())
    
for fifteen_passing_row in fifteen_passing_rows[1:]:
    fifteen_passing_row_data = fifteen_passing_row.find_all('td')
    fifteen_passing_attempts.append(fifteen_passing_row_data[1].text.strip())
    fifteen_passing_completions.append(fifteen_passing_row_data[2].text.strip())
    fifteen_passing_completion_percentage.append(fifteen_passing_row_data[3].text.strip())
    fifteen_passing_yards_per_attempt.append(fifteen_passing_row_data[4].text.strip())
    fifteen_passing_yards.append(fifteen_passing_row_data[5].text.strip())
    fifteen_passing_touchdowns.append(fifteen_passing_row_data[6].text.strip())
    fifteen_passing_interceptions.append(fifteen_passing_row_data[7].text.strip())
    fifteen_year.append('2015')
    
fifteen_passing_tableTitles[1] = "Pass Att"
fifteen_passing_tableTitles[6] = "Pass TD"

for fifteen_rushing_table in fifteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    fifteen_rushing_titles = fifteen_rushing_table.find_all('th')
    fifteen_rushing_rows = fifteen_rushing_table.find_all('tr')

for fifteen_rushing_title in fifteen_rushing_titles:
    fifteen_rushing_tableTitles = [fifteen_rushing_title.text.strip() for title in fifteen_rushing_titles]

for fifteen_rushing_team_names in fifteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    fifteen_rushing_team_name.append(fifteen_rushing_team_names.text.strip())

fifteen_rushing_team_index = -1

for fifteen_rushing_row in fifteen_rushing_rows[1:]:
    fifteen_rushing_row_data = fifteen_rushing_row.find_all('td')
    fifteen_rushing_team_index = fifteen_rushing_team_index + 1
    fifteen_team_index = fifteen_passing_team_name.index(str(fifteen_rushing_team_name[fifteen_rushing_team_index]))
    fifteen_rushing_attempts[fifteen_team_index] = fifteen_rushing_row_data[1].text.strip()
    fifteen_rushing_yards[fifteen_team_index] = fifteen_rushing_row_data[2].text.strip()
    fifteen_yards_per_carry[fifteen_team_index] = fifteen_rushing_row_data[3].text.strip()
    fifteen_rushing_touchdowns[fifteen_team_index] = fifteen_rushing_row_data[4].text.strip()

fifteen_rushing_tableTitles[1] = "Rush Att"
fifteen_rushing_tableTitles[4] = "Rush TD"

#2014 Season
for fourteen_passing_table in fourteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    fourteen_passing_titles = fourteen_passing_table.find_all('th')
    fourteen_passing_rows = fourteen_passing_table.find_all('tr')

for fourteen_passing_title in fourteen_passing_titles:
    fourteen_passing_tableTitles = [fourteen_passing_title.text.strip() for fourteen_passing_title in fourteen_passing_titles]
    
for fourteen_team_name in fourteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    fourteen_passing_team_name.append(fourteen_team_name.text.strip())
    
for fourteen_passing_row in fourteen_passing_rows[1:]:
    fourteen_passing_row_data = fourteen_passing_row.find_all('td')
    fourteen_passing_attempts.append(fourteen_passing_row_data[1].text.strip())
    fourteen_passing_completions.append(fourteen_passing_row_data[2].text.strip())
    fourteen_passing_completion_percentage.append(fourteen_passing_row_data[3].text.strip())
    fourteen_passing_yards_per_attempt.append(fourteen_passing_row_data[4].text.strip())
    fourteen_passing_yards.append(fourteen_passing_row_data[5].text.strip())
    fourteen_passing_touchdowns.append(fourteen_passing_row_data[6].text.strip())
    fourteen_passing_interceptions.append(fourteen_passing_row_data[7].text.strip())
    fourteen_year.append('2014')
    
fourteen_passing_tableTitles[1] = "Pass Att"
fourteen_passing_tableTitles[6] = "Pass TD"

for fourteen_rushing_table in fourteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    fourteen_rushing_titles = fourteen_rushing_table.find_all('th')
    fourteen_rushing_rows = fourteen_rushing_table.find_all('tr')

for fourteen_rushing_title in fourteen_rushing_titles:
    fourteen_rushing_tableTitles = [fourteen_rushing_title.text.strip() for title in fourteen_rushing_titles]

for fourteen_rushing_team_names in fourteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    fourteen_rushing_team_name.append(fourteen_rushing_team_names.text.strip())

fourteen_rushing_team_index = -1

for fourteen_rushing_row in fourteen_rushing_rows[1:]:
    fourteen_rushing_row_data = fourteen_rushing_row.find_all('td')
    fourteen_rushing_team_index = fourteen_rushing_team_index + 1
    fourteen_team_index = fourteen_passing_team_name.index(str(fourteen_rushing_team_name[fourteen_rushing_team_index]))
    fourteen_rushing_attempts[fourteen_team_index] = fourteen_rushing_row_data[1].text.strip()
    fourteen_rushing_yards[fourteen_team_index] = fourteen_rushing_row_data[2].text.strip()
    fourteen_yards_per_carry[fourteen_team_index] = fourteen_rushing_row_data[3].text.strip()
    fourteen_rushing_touchdowns[fourteen_team_index] = fourteen_rushing_row_data[4].text.strip()

fourteen_rushing_tableTitles[1] = "Rush Att"
fourteen_rushing_tableTitles[4] = "Rush TD"

#2013 Season
for thirteen_passing_table in thirteen_passing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    thirteen_passing_titles = thirteen_passing_table.find_all('th')
    thirteen_passing_rows = thirteen_passing_table.find_all('tr')

for thirteen_passing_title in thirteen_passing_titles:
    thirteen_passing_tableTitles = [thirteen_passing_title.text.strip() for thirteen_passing_title in thirteen_passing_titles]
    
for thirteen_team_name in thirteen_passing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    thirteen_passing_team_name.append(thirteen_team_name.text.strip())
    
for thirteen_passing_row in thirteen_passing_rows[1:]:
    thirteen_passing_row_data = thirteen_passing_row.find_all('td')
    thirteen_passing_attempts.append(thirteen_passing_row_data[1].text.strip())
    thirteen_passing_completions.append(thirteen_passing_row_data[2].text.strip())
    thirteen_passing_completion_percentage.append(thirteen_passing_row_data[3].text.strip())
    thirteen_passing_yards_per_attempt.append(thirteen_passing_row_data[4].text.strip())
    thirteen_passing_yards.append(thirteen_passing_row_data[5].text.strip())
    thirteen_passing_touchdowns.append(thirteen_passing_row_data[6].text.strip())
    thirteen_passing_interceptions.append(thirteen_passing_row_data[7].text.strip())
    thirteen_year.append('2013')
    
thirteen_passing_tableTitles[1] = "Pass Att"
thirteen_passing_tableTitles[6] = "Pass TD"

for thirteen_rushing_table in thirteen_rushing_soup.find_all('table', class_ = "d3-o-table d3-o-table--detailed d3-o-team-stats--detailed d3-o-table--sortable {sortlist: [[0,0]], sortinitialorder: 'asc'}"):
    thirteen_rushing_titles = thirteen_rushing_table.find_all('th')
    thirteen_rushing_rows = thirteen_rushing_table.find_all('tr')

for thirteen_rushing_title in thirteen_rushing_titles:
    thirteen_rushing_tableTitles = [thirteen_rushing_title.text.strip() for title in thirteen_rushing_titles]

for thirteen_rushing_team_names in thirteen_rushing_soup.find_all('div', class_ = "d3-o-club-fullname"):
    thirteen_rushing_team_name.append(thirteen_rushing_team_names.text.strip())

thirteen_rushing_team_index = -1

for thirteen_rushing_row in thirteen_rushing_rows[1:]:
    thirteen_rushing_row_data = thirteen_rushing_row.find_all('td')
    thirteen_rushing_team_index = thirteen_rushing_team_index + 1
    thirteen_team_index = thirteen_passing_team_name.index(str(thirteen_rushing_team_name[thirteen_rushing_team_index]))
    thirteen_rushing_attempts[thirteen_team_index] = thirteen_rushing_row_data[1].text.strip()
    thirteen_rushing_yards[thirteen_team_index] = thirteen_rushing_row_data[2].text.strip()
    thirteen_yards_per_carry[thirteen_team_index] = thirteen_rushing_row_data[3].text.strip()
    thirteen_rushing_touchdowns[thirteen_team_index] = thirteen_rushing_row_data[4].text.strip()

thirteen_rushing_tableTitles[1] = "Rush Att"
thirteen_rushing_tableTitles[4] = "Rush TD"

# %% [markdown]
# #### Change Team Names So Each Team Only Has One Team Name

# %%
team_names = twenty_three_passing_team_name + twenty_two_passing_team_name + twenty_one_passing_team_name + twenty_passing_team_name + nineteen_passing_team_name + eighteen_passing_team_name + seventeen_passing_team_name + sixteen_passing_team_name + fifteen_passing_team_name + fourteen_passing_team_name + thirteen_passing_team_name  

team_name_index = 0

for football_team in team_names:
    if football_team == 'Niners':
        team_names[team_name_index] = '49ers'
        team_name_index += 1
    elif football_team == 'Redskins':
        team_names[team_name_index] = 'Commanders'
        team_name_index += 1
    elif football_team == 'Football Team':
        team_names[team_name_index] = 'Commanders'
        team_name_index += 1
    else:
        team_name_index += 1

# %% [markdown]
# #### Creating Dataframe For All 32 Teams Over The Past 10 Seasons

# %%
#Total Stats DataFrame
stats_dataframe = pd.DataFrame()
stats_dataframe['Team'] = team_names
stats_dataframe['Pass Att'] = twenty_three_passing_attempts + twenty_two_passing_attempts + twenty_one_passing_attempts + twenty_passing_attempts + nineteen_passing_attempts + eighteen_passing_attempts + seventeen_passing_attempts + sixteen_passing_attempts + fifteen_passing_attempts + fourteen_passing_attempts + thirteen_passing_attempts  
stats_dataframe['Cmp'] = twenty_three_passing_completions + twenty_two_passing_completions + twenty_one_passing_completions + twenty_passing_completions + nineteen_passing_completions + eighteen_passing_completions + seventeen_passing_completions + sixteen_passing_completions + fifteen_passing_completions + fourteen_passing_completions + thirteen_passing_completions  
stats_dataframe['Cmp %'] = twenty_three_passing_completion_percentage + twenty_two_passing_completion_percentage + twenty_one_passing_completion_percentage + twenty_passing_completion_percentage + nineteen_passing_completion_percentage + eighteen_passing_completion_percentage + seventeen_passing_completion_percentage + sixteen_passing_completion_percentage + fifteen_passing_completion_percentage + fourteen_passing_completion_percentage + thirteen_passing_completion_percentage  
stats_dataframe['Yds/Att'] = twenty_three_passing_yards_per_attempt + twenty_two_passing_yards_per_attempt + twenty_one_passing_yards_per_attempt + twenty_passing_yards_per_attempt + nineteen_passing_yards_per_attempt + eighteen_passing_yards_per_attempt + seventeen_passing_yards_per_attempt + sixteen_passing_yards_per_attempt + fifteen_passing_yards_per_attempt + fourteen_passing_yards_per_attempt + thirteen_passing_yards_per_attempt  
stats_dataframe['Pass Yds'] = twenty_three_passing_yards + twenty_two_passing_yards + twenty_one_passing_yards + twenty_passing_yards + nineteen_passing_yards + eighteen_passing_yards + seventeen_passing_yards + sixteen_passing_yards + fifteen_passing_yards + fourteen_passing_yards + thirteen_passing_yards  
stats_dataframe['Pass TD'] = twenty_three_passing_touchdowns + twenty_two_passing_touchdowns + twenty_one_passing_touchdowns + twenty_passing_touchdowns + nineteen_passing_touchdowns + eighteen_passing_touchdowns + seventeen_passing_touchdowns + sixteen_passing_touchdowns + fifteen_passing_touchdowns + fourteen_passing_touchdowns + thirteen_passing_touchdowns  
stats_dataframe['INT'] = twenty_three_passing_interceptions + twenty_two_passing_interceptions + twenty_one_passing_interceptions + twenty_passing_interceptions + nineteen_passing_interceptions + eighteen_passing_interceptions + seventeen_passing_interceptions + sixteen_passing_interceptions + fifteen_passing_interceptions + fourteen_passing_interceptions + thirteen_passing_interceptions  
stats_dataframe['Rush Att'] = twenty_three_rushing_attempts + twenty_two_rushing_attempts + twenty_one_rushing_attempts + twenty_rushing_attempts + nineteen_rushing_attempts + eighteen_rushing_attempts + seventeen_rushing_attempts + sixteen_rushing_attempts + fifteen_rushing_attempts + fourteen_rushing_attempts + thirteen_rushing_attempts  
stats_dataframe['Rush Yds'] = twenty_three_rushing_yards + twenty_two_rushing_yards + twenty_one_rushing_yards + twenty_rushing_yards + nineteen_rushing_yards + eighteen_rushing_yards + seventeen_rushing_yards + sixteen_rushing_yards + fifteen_rushing_yards + fourteen_rushing_yards + thirteen_rushing_yards  
stats_dataframe['Yds/Crry'] = twenty_three_yards_per_carry + twenty_two_yards_per_carry + twenty_one_yards_per_carry + twenty_yards_per_carry + nineteen_yards_per_carry + eighteen_yards_per_carry + seventeen_yards_per_carry + sixteen_yards_per_carry + fifteen_yards_per_carry + fourteen_yards_per_carry + thirteen_yards_per_carry  
stats_dataframe['Rush TD'] = twenty_three_rushing_touchdowns + twenty_two_rushing_touchdowns + twenty_one_rushing_touchdowns + twenty_rushing_touchdowns + nineteen_rushing_touchdowns + eighteen_rushing_touchdowns + seventeen_rushing_touchdowns + sixteen_rushing_touchdowns + fifteen_rushing_touchdowns + fourteen_rushing_touchdowns + thirteen_rushing_touchdowns
stats_dataframe[['Pass Att', 'Cmp', 'Pass Yds', 'Pass TD', 'INT', 'Rush Att', 'Rush Yds', 'Rush TD']] = stats_dataframe[['Pass Att', 'Cmp', 'Pass Yds', 'Pass TD', 'INT', 'Rush Att', 'Rush Yds', 'Rush TD']].astype(int)
stats_dataframe[['Cmp %', 'Yds/Att', 'Yds/Crry']] = stats_dataframe[['Cmp %', 'Yds/Att', 'Yds/Crry']].astype(float)
stats_dataframe['Total Yds'] = stats_dataframe['Pass Yds'] + stats_dataframe['Rush Yds']
stats_dataframe["Total TD"] = stats_dataframe['Pass TD'] + stats_dataframe['Rush TD']
stats_dataframe['Year'] = twenty_three_year + twenty_two_year + twenty_one_year + twenty_year + nineteen_year + eighteen_year + seventeen_year + sixteen_year + fifteen_year + fourteen_year + thirteen_year

# %%
stats_dataframe
# Out:
#            Team  Pass Att  Cmp  Cmp %  Yds/Att  Pass Yds  Pass TD  INT  \
# 0    Commanders       636  407   64.0      6.6      4174       24   21
# 1        Chiefs       635  421   66.3      6.9      4383       28   17
# 2      Chargers       632  409   64.7      6.8      4312       24    8
# 3       Vikings       631  424   67.2      7.4      4700       30   19
# 4        Browns       624  355   56.9      6.4      4011       24   23
# ..          ...       ...  ...    ...      ...       ...      ...  ...
# 347        Rams       506  301   59.5      6.6      3360       22   11
# 348        Jets       480  266   55.4      6.8      3270       13   22
# 349    Panthers       473  292   61.7      7.1      3379       24   13
# 350    Seahawks       420  267   63.6      8.4      3508       27    9
# 351       49ers       417  244   58.5      7.7      3210       21    8
#
#      Rush Att  Rush Yds  Yds/Crry  Rush TD  Total Yds  Total TD  Year
# ...

# %% [markdown]
# #### Saving Dataframe to a CSV File

# %%
stats_dataframe.to_csv(r'C:\Users\docto\OneDrive\Desktop\NFL_Offensive_Stats.csv', index = False)

# %% [markdown]
# # Offensive Trends From 2013 - 2023

# %%
years = range(2013,2024)
yards_stat_sums = stats_dataframe.groupby('Year')[['Pass Att', 'Pass Yds', 'Pass TD', 'Rush Att', 'Rush Yds','Rush TD','Total Yds', 'Total TD']].sum()
yards_stat_mean = stats_dataframe.groupby('Year')[['Cmp %', 'Yds/Att', 'Yds/Crry']].mean()

# %% [markdown]
# ## Is The NFL a Pass First League?

# %%
plt.title("Passing Attempts From 2013 - 2023")
plt.plot(years, yards_stat_sums['Pass Att'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Passing Attempts')
plt.xticks(years)
plt.show()

plt.title("Rushing Attempts From 2013 - 2023")
plt.plot(years, yards_stat_sums['Rush Att'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Rushing Attempts')
plt.xticks(years)
plt.show()

plt.title("Passing vs. Rushing Attempts From 2013 - 2023")
plt.plot(years, yards_stat_sums['Pass Att'], marker = 'o', label = "Passing Attempts")
plt.plot(years, yards_stat_sums['Rush Att'], marker = 'o', label = "Rushing Attempts")
plt.xlabel('Year')
plt.ylabel('Attempts')
plt.legend(loc = 'center left')
plt.xticks(years)
plt.show()

# %% [markdown]
# ## Efficiency Of Offenses From 2013 - 2023

# %%
plt.title("Passing Completion Percentage From 2013 - 2023")
plt.plot(years, yards_stat_mean['Cmp %'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Completion Percentage (%)')
plt.xticks(years)
plt.show()

plt.title("Passing Yards Per Attempts From 2013 - 2023")
plt.plot(years, yards_stat_mean['Yds/Att'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Passing Yards Per Attempt')
plt.xticks(years)
plt.show()

plt.title("Rushing Yards Per Carry From 2013 - 2023")
plt.plot(years, yards_stat_mean['Yds/Crry'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Rushing Yards Per Carry')
plt.xticks(years)
plt.show()

# %% [markdown]
# ## Passing + Rushing Yard Trends From 2013 - 2023

# %%
plt.title("Passing Yards From 2013 - 2023")
plt.plot(years, yards_stat_sums['Pass Yds'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Passing Yards')
plt.xticks(years)
plt.show()

plt.title("Rushing Yards From 2013 - 2023")
plt.plot(years, yards_stat_sums['Rush Yds'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Rushing Yards')
plt.xticks(years)
plt.show()

plt.title("Total Yards From 2013 - 2023")
plt.plot(years, yards_stat_sums['Total Yds'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Total Yards')
plt.xticks(years)
plt.show()

# %% [markdown]
# ## Scoring Trends From 2013 - 2023

# %%
plt.title("Passing TDs From 2013 - 2023")
plt.plot(years, yards_stat_sums['Pass TD'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Passing Touchdowns')
plt.xticks(years)
plt.show()

plt.title("Rushing TDs From 2013 - 2023")
plt.plot(years, yards_stat_sums['Rush TD'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Rushing Touchdowns')
plt.xticks(years)
plt.show()

plt.title("Total TDs From 2013 - 2023")
plt.plot(years, yards_stat_sums['Total TD'], marker = 'o')
plt.xlabel('Year')
plt.ylabel('Total Touchdowns')
plt.xticks(years)
plt.show()

# %% [markdown]
# # How Important is Being Efficient On Offence?

# %%
plt.title('Correlation between Passing Yards Per Attempt and Passing Touchdowns')
plt.xlabel('Passing Touchdowns')
plt.ylabel('Yards Per Passing Attempt')
plt.scatter(x = stats_dataframe['Yds/Att'], y = stats_dataframe['Pass TD'])
plt.show()

plt.title('Correlation between Rushing Yards Per Carry and Rushing Touchdowns')
plt.xlabel('Passing Touchdowns')
plt.ylabel('Yards Per Rushing Carry')
plt.scatter(x = stats_dataframe['Yds/Crry'], y = stats_dataframe['Rush TD'])
plt.show()

# %% [markdown]
# # Team Statistical Comparisons From 2013 - 2023

# %%
teams = [team_sort for team_sort, stats_dataframe in stats_dataframe.groupby('Team')]
team_stat_sum = stats_dataframe.groupby(stats_dataframe['Team'])[['Pass Att', 'Pass Yds', 'Pass TD', 'Rush Att', 'Rush Yds','Rush TD','Total Yds', 'Total TD']].sum()
team_stat_mean = stats_dataframe.groupby(stats_dataframe['Team'])[['Cmp %', 'Yds/Att', 'Yds/Crry']].mean()

# %% [markdown]
# ## Team Offensive Efficiency

# %%
team_stat_mean['Cmp %'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Passing Completion Percentage Average From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Completion Percentage Average')
plt.show() 

team_stat_mean['Yds/Att'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Passing Yards Per Attempt Average From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Passing Yards Per Attempt')
plt.show()
team_stat_mean['Yds/Crry'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Rushing Yards Per Attempt Average From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Rushing Yards Per Carry')
plt.show()

# %% [markdown]
# ## Team Offensive Yards Gained

# %%
team_stat_sum['Pass Yds'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Passing Yards Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Passing Yards')
plt.show()

team_stat_sum['Rush Yds'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Rushing Yards Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Rushing Yards')
plt.show()

team_stat_sum['Total Yds'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Total Yards Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Total Yards')
plt.show()

# %% [markdown]
# ## Team Scoring From 2013 - 2023

# %%
team_stat_sum['Pass TD'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Passing Touchdowns Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Passing Touchdowns')
plt.show()

team_stat_sum['Rush TD'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Rushing Touchdowns Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Rushing Touchdowns')
plt.show()

team_stat_sum['Total TD'].sort_values().plot.bar(width = .75, edgecolor = 'black', title = 'Total Touchdowns Sums From 2013 - 2023')
plt.xlabel('Team')
plt.ylabel('Total Touchdowns')
plt.show()

# %% [markdown]
# ## Best and Worst Scoring Teams

# %%
specific_team_df = pd.DataFrame()
specific_team_df = stats_dataframe.copy(deep = True)
specific_team_df['Team'] = stats_dataframe['Year'] + ' ' + stats_dataframe['Team']

# %% [markdown]
# ### Best and Worst Passing Touchdowns Scored

# %%
top_ten_pass_td = specific_team_df.nlargest(n = 10, columns = 'Pass TD')
plt.title('Top Ten Passing Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Passing Touchdowns')
plt.bar(x = top_ten_pass_td['Team'], height = top_ten_pass_td['Pass TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()

low_ten_pass_td = specific_team_df.nsmallest(n = 10, columns = 'Pass TD')
plt.title('Worst Ten Passing Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Passing Touchdowns')
plt.bar(x = low_ten_pass_td['Team'], height = low_ten_pass_td['Pass TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### Best and Worst Rushing Touchdowns Scored

# %%
top_ten_rush_td = specific_team_df.nlargest(n = 10, columns = 'Rush TD')
plt.title('Top Ten Rushing Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Rushing Touchdowns')
plt.bar(x = top_ten_rush_td['Team'], height = top_ten_rush_td['Rush TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()

low_ten_rush_td = specific_team_df.nsmallest(n = 10, columns = 'Rush TD')
plt.title('Worst Ten Rushing Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Rushing Touchdowns')
plt.bar(x = low_ten_rush_td['Team'], height = low_ten_rush_td['Rush TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()

# %% [markdown]
# ### Best and Worst Total Touchdowns Scored

# %%
top_ten_total_td = specific_team_df.nlargest(n = 10, columns = 'Total TD')
plt.title('Top Ten Total Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Total Touchdowns')
plt.bar(x = top_ten_total_td['Team'], height = top_ten_total_td['Total TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()

low_ten_total_td = specific_team_df.nsmallest(n = 10, columns = 'Total TD')
plt.title('Worst Ten Total Touchdowns Scored')
plt.xlabel('Team')
plt.ylabel('Total Touchdowns')
plt.bar(x = low_ten_total_td['Team'], height = low_ten_total_td['Total TD'], edgecolor = 'black')
plt.xticks(rotation = 'vertical')
plt.show()
